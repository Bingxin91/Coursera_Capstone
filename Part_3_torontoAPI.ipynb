# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json, lxml
from geopy.geocoders import Nominatim 
import requests 
from pandas.io.json import json_normalize 
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
from bs4 import BeautifulSoup
import warnings
import folium

# %% [markdown]
# Get data from Wiki

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
soup = BeautifulSoup(requests.get(url).text)

table = soup.find('div', class_='mw-parser-output').table.tbody

cols = ['PostalCode', 'Borough', 'Neighbourhood']
data = dict({key:[]*len(cols) for key in cols})

for row in table.find_all('tr'):
    for i,column in zip(row.find_all('td'),cols):
        i = i.text
        i = i.replace('\n', '')
        data[column].append(i)

df = pd.DataFrame.from_dict(data=data)[cols]

# %% [markdown]
# Clean Data

# %%
df = df[df.Borough != 'Not assigned'] #Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

df2 = df[df.Neighbourhood != "Not assigned"]
df1 = df[df.Neighbourhood == "Not assigned"]
df1['Neighbourhood'] = df1['Borough'] #If a cell has a borough but a Not assigned  neighborhood, then the neighborhood will be the same as the borough.
#More than one neighborhood can exist in one postal code area. 
df = df1.append(df2)
print(len(df))
i = 0
postcodes = []
for index, row in df.iterrows():
  if i == 0:
    df_sel = pd.DataFrame(columns=cols)
    df_sel = df_sel.append({'PostalCode': row[0], 'Borough': row[1], 'Neighbourhood': row[2]}, ignore_index=True)
    postcodes.append(row[0])
  else:
    if row[0] in postcodes:
      existing_n = df_sel.loc[df['PostalCode'] == row[0], 'Neighbourhood']
      new_n = existing_n+","+ row[2]
      df_sel = df_sel.append({'PostalCode': row[0], 'Borough': row[1], 'Neighbourhood': new_n}, ignore_index=True)
    else:
      df_sel = df_sel.append({'PostalCode': row[0], 'Borough': row[1], 'Neighbourhood': row[2]}, ignore_index=True)
  i = i+1

df = df_sel
print(df.head())
print(df.shape)
# Out:
# 103
#   PostalCode           Borough                                Neighbourhood
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# (103, 3)

# %% [markdown]
# Get coordinates

# %%
# !wget http://cocl.us/Geospatial_data
# Out:
# --2021-01-11 22:01:27--  http://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 169.63.96.176, 169.63.96.194
# Connecting to cocl.us (cocl.us)|169.63.96.176|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data [following]
# --2021-01-11 22:01:27--  https://cocl.us/Geospatial_data
# Connecting to cocl.us (cocl.us)|169.63.96.176|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2021-01-11 22:01:28--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.24.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.24.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2021-01-11 22:01:28--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2021-01-11 22:01:28--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.24.201
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.24.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!eT6xdGgGWSyGcXR21zD7_JHL9PIBhF4aKiify73U17cQYOD0uCdK4rax4NoGfjSK9GlwuUy7wax3btJWjRKjdoovgH_VRxZrvN_jbXcEsALf0I2ioEA-ddrCRYWtc2jK3u9rHmCO24TCkfUiumzVQUjtHkNdHvdU78-WRdkimKscQZqvBzdUGkI3q9Nxu9kWxZs3ClgLCRgEHK57RJE5C9ZZOGpbJgIQRRCEzV6oGjKjEVYgqhikgpY2kqc7uWTrwEneXsxG00h9fCd7T6mB6lHdc3h4oFEJTaPY3_JC2fqAwmAUVUrLhN7xuKJhzcqXQD-VHB0alnoT_Ovt6kCNY52FwlPHQTRfVvaUVMbfZWbGh53uTucceHaCcvEUZ3VTmLvMqli1g7ToJyybjM7oqQRVykvRXneI79X7unpus2_3eHaFXQjdON2y4PtpxpJoXtwJMikLyMpCx4fp6gx1sgMNSTX73kjCGfYIT9uUExzG-yuaFH8vtvMHY8Ornk18qvenXUQTY6oY1t89BxPB4yw_jkbldyRPB3z3rStwn39pej0PgEf0JqEINlG4eBvc_TuA7k2sATNmNbw5Me3KOI7nZXgFW2UCICxELxqfg7djCvWbq6Rhh2OVFW0Nx6F8rPr9-BxN6i8M99YjCL1-hF9qVPtbkt_iSXJzpfCs1ZhS8JCeN4wftjx2BoFPX2DMK0GgmFrMBggU9bPn_hRIpMKFPkFwL3NJY9uDJdhImYkoHIqHkHXaYwq1ZoeUxq56_1HP3xwC-8Odmx1HA2WDkQlebrm5Vm7fTlOEIiSVUwLYk9gt_XdWdfHNPj6aOz2lTAZ3_YmeNkIhZcIyuA97k1TxaZLoAGs5IYs0IkuIIpdzY9bvecXvUhHSQX5xqNTA7P_FMuWvNQ5CSYmH8bUuIMCNq_k8S8KAjWO3WUNednSpQcOazJ8u9maQZ8YmANLIOhHH5y905sayb4Hkssl7U8cZ4sprsUxgXRXXP3cOFAW2maPaN5IxmJhhwkbaoCP5yck4eIrSQIwPCp1vVJ8vZXk58b1F1alSK1oT4ri9zd6_WV5obVarP_0msFJV-1drejCsuRXgGoTLCiuekGwqhlQ6MKk78zlX59OMctluY6mIZw7u1RzCioNN0SA-OKCGLzM0W9h5TmR6vBqB4Ojy7Fi9OPaRXWu_RlI-97GncwtTu38p-Epx99lFsHSoqIy03CsXu2_lmjmaInSqpTVcKalpiEDSP1EDe7fGK4pJKpNskFqrBzOTq-fucc_dUViN2qDEmGTIAARIphgyd0pwzwJDfwmizGFqAbmR2iC0sXxQZjetPyTCfuzgMsfoZNQVrzF2tG1Be1ohRDE4VrjyHsc76DjXNoOj9s1ovb8nqOD5qglqrK28_KiWORvpFfC1bx5bG4QFAsCc1AMQe7ACjIsCATyWXQ1Y4Ux5kHzYiLA./download [following]
# --2021-01-11 22:01:29--  https://public.boxcloud.com/d/1/b1!eT6xdGgGWSyGcXR21zD7_JHL9PIBhF4aKiify73U17cQYOD0uCdK4rax4NoGfjSK9GlwuUy7wax3btJWjRKjdoovgH_VRxZrvN_jbXcEsALf0I2ioEA-ddrCRYWtc2jK3u9rHmCO24TCkfUiumzVQUjtHkNdHvdU78-WRdkimKscQZqvBzdUGkI3q9Nxu9kWxZs3ClgLCRgEHK57RJE5C9ZZOGpbJgIQRRCEzV6oGjKjEVYgqhikgpY2kqc7uWTrwEneXsxG00h9fCd7T6mB6lHdc3h4oFEJTaPY3_JC2fqAwmAUVUrLhN7xuKJhzcqXQD-VHB0alnoT_Ovt6kCNY52FwlPHQTRfVvaUVMbfZWbGh53uTucceHaCcvEUZ3VTmLvMqli1g7ToJyybjM7oqQRVykvRXneI79X7unpus2_3eHaFXQjdON2y4PtpxpJoXtwJMikLyMpCx4fp6gx1sgMNSTX73kjCGfYIT9uUExzG-yuaFH8vtvMHY8Ornk18qvenXUQTY6oY1t89BxPB4yw_jkbldyRPB3z3rStwn39pej0PgEf0JqEINlG4eBvc_TuA7k2sATNmNbw5Me3KOI7nZXgFW2UCICxELxqfg7djCvWbq6Rhh2OVFW0Nx6F8rPr9-BxN6i8M99YjCL1-hF9qVPtbkt_iSXJzpfCs1ZhS8JCeN4wftjx2BoFPX2DMK0GgmFrMBggU9bPn_hRIpMKFPkFwL3NJY9uDJdhImYkoHIqHkHXaYwq1ZoeUxq56_1HP3xwC-8Odmx1HA2WDkQlebrm5Vm7fTlOEIiSVUwLYk9gt_XdWdfHNPj6aOz2lTAZ3_YmeNkIhZcIyuA97k1TxaZLoAGs5IYs0IkuIIpdzY9bvecXvUhHSQX5xqNTA7P_FMuWvNQ5CSYmH8bUuIMCNq_k8S8KAjWO3WUNednSpQcOazJ8u9maQZ8YmANLIOhHH5y905sayb4Hkssl7U8cZ4sprsUxgXRXXP3cOFAW2maPaN5IxmJhhwkbaoCP5yck4eIrSQIwPCp1vVJ8vZXk58b1F1alSK1oT4ri9zd6_WV5obVarP_0msFJV-1drejCsuRXgGoTLCiuekGwqhlQ6MKk78zlX59OMctluY6mIZw7u1RzCioNN0SA-OKCGLzM0W9h5TmR6vBqB4Ojy7Fi9OPaRXWu_RlI-97GncwtTu38p-Epx99lFsHSoqIy03CsXu2_lmjmaInSqpTVcKalpiEDSP1EDe7fGK4pJKpNskFqrBzOTq-fucc_dUViN2qDEmGTIAARIphgyd0pwzwJDfwmizGFqAbmR2iC0sXxQZjetPyTCfuzgMsfoZNQVrzF2tG1Be1ohRDE4VrjyHsc76DjXNoOj9s1ovb8nqOD5qglqrK28_KiWORvpFfC1bx5bG4QFAsCc1AMQe7ACjIsCATyWXQ1Y4Ux5kHzYiLA./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.24.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.24.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_data’
#
# Geospatial_data     100%[===================>]   2.82K  --.-KB/s    in 0s
#
# 2021-01-11 22:01:29 (524 MB/s) - ‘Geospatial_data’ saved [2891/2891]

# %%
coords = pd.read_csv('Geospatial_data')
coords.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Create dataframe

# %%
df = pd.merge(df, coords, how= 'inner', left_on = 'PostalCode',right_on = 'Postal Code')
df.head()
Neighborhood = df

# %%
Neighborhood.head()
# Out:
#   PostalCode           Borough  ...   Latitude  Longitude
# 0        M3A        North York  ...  43.753259 -79.329656
# 1        M4A        North York  ...  43.725882 -79.315572
# 2        M5A  Downtown Toronto  ...  43.654260 -79.360636
# 3        M6A        North York  ...  43.718518 -79.464763
# 4        M7A  Downtown Toronto  ...  43.662301 -79.389494
#
# [5 rows x 6 columns]

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(Neighborhood['Borough'].unique()),
        Neighborhood.shape[0]
    )
)
# Out:
# The dataframe has 10 boroughs and 103 neighborhoods.

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.6534817, -79.3839347.

# %% [markdown]
# Geovisualization

# %%
map_Toronto = folium.Map(location=[43.6534817, -79.3839347], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhoods in zip(Neighborhood['Latitude'], Neighborhood['Longitude'], Neighborhood['Borough'], Neighborhood['Neighbourhood']):
    label = '{}, {}'.format(neighborhoods, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
#map_Toronto = folium.Map(location=[43.6534817, -79.3839347], zoom_start=10)

map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_e4d3d95df7c74990a1ae369807ab5e49%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e4d3d95df7c74990a1ae369807ab5e49%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_e4d3d95df7c74990a1ae369807ab5e49%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_e4d3d95df7c74990a1ae369807ab5e49%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_8aba4bfa771a485ea7a22b93ec2b2fd9%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %%
CLIENT_ID = '5FQ5VZNE4TJSZPBD05XD0W01LXHSZ4DNFEHYRUXCFHP01PHL' # your Foursquare ID
CLIENT_SECRET = 'QJ3TK43SVE3X5EOLMR2FOXKPJ4YLXYAFESP4B1P053WZBN3D' # your Foursquare Secret
VERSION = '20180605'
LIMIT = 100 

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 5FQ5VZNE4TJSZPBD05XD0W01LXHSZ4DNFEHYRUXCFHP01PHL
# CLIENT_SECRET:QJ3TK43SVE3X5EOLMR2FOXKPJ4YLXYAFESP4B1P053WZBN3D

# %%
def get_vanues(names, lat, lon):
  radius=1000
  CLIENT_ID = '5FQ5VZNE4TJSZPBD05XD0W01LXHSZ4DNFEHYRUXCFHP01PHL' # your Foursquare ID
  CLIENT_SECRET = 'QJ3TK43SVE3X5EOLMR2FOXKPJ4YLXYAFESP4B1P053WZBN3D' # your Foursquare Secret
  VERSION = '20180605'
  LIMIT = 100 
  all_list=[]
  for name, lat, lng in zip(names, lat, lon):
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, LIMIT)
    results = requests.get(url).json()["response"]['groups'][0]['items']
    all_list.append([(name, lat, lng, v['venue']['name'], v['venue']['location']['lat'], v['venue']['location']['lng'],v['venue']['categories'][0]['name']) for v in results])

  all_vanuess = pd.DataFrame([item for venue in all_list for item in venue])
  all_vanuess.columns = ['Neighbourhood','Neighbourhood Latitude', 'Neighbourhood Longitude','Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category']
    
  return all_vanuess

# %%
toronto_venues = get_vanues(names=Neighborhood['Neighbourhood'],lat=Neighborhood['Latitude'],lon=Neighborhood['Longitude'])

# %%
toronto_venues.head()
# Out:
#   Neighbourhood  Neighbourhood Latitude  ...  Venue Longitude        Venue Category
# 0     Parkwoods               43.753259  ...       -79.324719  Caribbean Restaurant
# 1     Parkwoods               43.753259  ...       -79.326368                  Café
# 2     Parkwoods               43.753259  ...       -79.332140                  Park
# 3     Parkwoods               43.753259  ...       -79.324630         Grocery Store
# 4     Parkwoods               43.753259  ...       -79.324949     Fish & Chips Shop
#
# [5 rows x 7 columns]

# %% [markdown]
# Group results

# %%
toronto_venues.groupby('Neighbourhood').count()
# Out:
#                                                  Neighbourhood Latitude  ...  Venue Category
# Neighbourhood                                                            ...
# Agincourt                                                            45  ...              45
# Alderwood, Long Branch                                               24  ...              24
# Bathurst Manor, Wilson Heights, Downsview North                      30  ...              30
# Bayview Village                                                      15  ...              15
# Bedford Park, Lawrence Manor East                                    40  ...              40
# ...                                                                 ...  ...             ...
# Willowdale, Willowdale West                                          10  ...              10
# Woburn                                                                9  ...               9
# Woodbine Heights                                                     27  ...              27
# York Mills West                                                      18  ...              18
# York Mills, Silver Hills                                              4  ...               4
#
# [98 rows x 6 columns]

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 330 uniques categories.

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighbourhood'] = toronto_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot.head()
# Out:
#   Neighbourhood  ATM  Accessories Store  ...  Women's Store  Yoga Studio  Zoo
# 0     Parkwoods    0                  0  ...              0            0    0
# 1     Parkwoods    0                  0  ...              0            0    0
# 2     Parkwoods    0                  0  ...              0            0    0
# 3     Parkwoods    0                  0  ...              0            0    0
# 4     Parkwoods    0                  0  ...              0            0    0
#
# [5 rows x 331 columns]

# %%
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()
toronto_grouped
# Out:
#                                       Neighbourhood  ATM  ...  Yoga Studio  Zoo
# 0                                         Agincourt  0.0  ...          0.0  0.0
# 1                            Alderwood, Long Branch  0.0  ...          0.0  0.0
# 2   Bathurst Manor, Wilson Heights, Downsview North  0.0  ...          0.0  0.0
# 3                                   Bayview Village  0.0  ...          0.0  0.0
# 4                 Bedford Park, Lawrence Manor East  0.0  ...          0.0  0.0
# ..                                              ...  ...  ...          ...  ...
# 93                      Willowdale, Willowdale West  0.0  ...          0.0  0.0
# 94                                           Woburn  0.0  ...          0.0  0.0
# 95                                 Woodbine Heights  0.0  ...          0.0  0.0
# 96                                  York Mills West  0.0  ...          0.0  0.0
# 97                         York Mills, Silver Hills  0.0  ...          0.0  0.0
#
# [98 rows x 331 columns]

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agincourt----
#                 venue  freq
# 0  Chinese Restaurant  0.13
# 1       Shopping Mall  0.07
# 2              Bakery  0.04
# 3         Pizza Place  0.04
# 4      Sandwich Place  0.04
#
#
# ----Alderwood, Long Branch----
#                venue  freq
# 0     Discount Store  0.12
# 1        Pizza Place  0.08
# 2           Pharmacy  0.08
# 3  Convenience Store  0.04
# 4               Park  0.04
#
#
# ----Bathurst Manor, Wilson Heights, Downsview North----
#          venue  freq
# 0  Pizza Place  0.07
# 1         Bank  0.07
# 2         Park  0.07
# 3  Coffee Shop  0.07
# 4  Bridal Shop  0.03
#
#
# ----Bayview Village----
#                  venue  freq
# 0          Gas Station  0.13
# 1                 Bank  0.13
# 2        Grocery Store  0.13
# 3  Japanese Restaurant  0.13
# 4   Chinese Restaurant  0.07
#
#
# ----Bedford Park, Lawrence Manor East----
#                 venue  freq
# 0  Italian Restaurant  0.08
# 1         Coffee Shop  0.08
# 2                Bank  0.05
# 3                Park  0.05
# 4      Sandwich Place  0.05
#
#
# ----Berczy Park----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                 Café  0.06
# 2                 Park  0.04
# 3                Hotel  0.04
# 4  Japanese Restaurant  0.04
#
#
# ----Birch Cliff, Cliffside West----
#              venue  freq
# 0             Park  0.21
# 1   Ice Cream Shop  0.07
# 2  College Stadium  0.07
# 3             Café  0.07
# 4     Skating Rink  0.07
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#          venue  freq
# 0         Café  0.07
# 1   Restaurant  0.06
# 2  Coffee Shop  0.06
# 3          Bar  0.05
# 4       Bakery  0.04
#
#
# ----Business reply mail Processing Centre, South Central Letter Processing Plant Toronto----
#                 venue  freq
# 0                Park  0.09
# 1         Pizza Place  0.06
# 2             Brewery  0.06
# 3  Italian Restaurant  0.04
# 4           Pet Store  0.04
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#               venue  freq
# 0       Coffee Shop  0.13
# 1   Harbor / Marina  0.13
# 2              Café  0.13
# 3    Scenic Lookout  0.07
# 4  Sculpture Garden  0.07
#
#
# ----Caledonia-Fairbanks----
#          venue  freq
# 0     Pharmacy  0.10
# 1  Pizza Place  0.10
# 2          ATM  0.05
# 3     Bus Line  0.05
# 4     Bus Stop  0.05
#
#
# ----Canada Post Gateway Processing Centre----
#                        venue  freq
# 0                Coffee Shop  0.11
# 1                      Hotel  0.06
# 2  Middle Eastern Restaurant  0.06
# 3         Mexican Restaurant  0.04
# 4        Fried Chicken Joint  0.04
#
#
# ----Cedarbrae----
#                venue  freq
# 0             Bakery  0.10
# 1        Coffee Shop  0.07
# 2  Indian Restaurant  0.07
# 3        Gas Station  0.07
# 4               Bank  0.07
#
#
# ----Central Bay Street----
#               venue  freq
# 0       Coffee Shop  0.10
# 1  Ramen Restaurant  0.04
# 2             Diner  0.03
# 3              Park  0.03
# 4              Café  0.03
#
#
# ----Christie----
#                 venue  freq
# 0   Korean Restaurant  0.12
# 1                Café  0.07
# 2         Coffee Shop  0.07
# 3       Grocery Store  0.05
# 4  Mexican Restaurant  0.03
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                 Park  0.04
# 2     Sushi Restaurant  0.03
# 3                 Café  0.03
# 4  Japanese Restaurant  0.03
#
#
# ----Clarks Corners, Tam O'Shanter, Sullivan----
#             venue  freq
# 0            Park  0.06
# 1    Intersection  0.06
# 2     Coffee Shop  0.06
# 3  Sandwich Place  0.06
# 4     Pizza Place  0.06
#
#
# ----Cliffside, Cliffcrest, Scarborough Village West----
#             venue  freq
# 0     Pizza Place  0.27
# 1  Ice Cream Shop  0.18
# 2           Beach  0.18
# 3      Sports Bar  0.09
# 4  Hardware Store  0.09
#
#
# ----Commerce Court, Victoria Hotel----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1                Café  0.07
# 2               Hotel  0.06
# 3  Seafood Restaurant  0.04
# 4          Restaurant  0.04
#
#
# ----Davisville----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1  Italian Restaurant  0.08
# 2    Sushi Restaurant  0.06
# 3                Café  0.04
# 4         Pizza Place  0.04
#
#
# ----Davisville North----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1  Italian Restaurant  0.05
# 2          Restaurant  0.04
# 3                Café  0.04
# 4        Dessert Shop  0.04
#
#
# ----Del Ray, Mount Dennis, Keelsdale and Silverthorn----
#                     venue  freq
# 0  Furniture / Home Store  0.19
# 1           Grocery Store  0.12
# 2          Discount Store  0.12
# 3           Shopping Mall  0.06
# 4    Fast Food Restaurant  0.06
#
#
# ----Don Mills----
#                  venue  freq
# 0           Restaurant  0.10
# 1  Japanese Restaurant  0.07
# 2          Coffee Shop  0.07
# 3                  Gym  0.06
# 4         Burger Joint  0.04
#
#
# ----Dorset Park, Wexford Heights, Scarborough Town Centre----
#                     venue  freq
# 0       Electronics Store  0.07
# 1             Coffee Shop  0.07
# 2  Furniture / Home Store  0.07
# 3    Fast Food Restaurant  0.05
# 4      Chinese Restaurant  0.05
#
#
# ----Downsview----
#                    venue  freq
# 0            Coffee Shop  0.09
# 1            Pizza Place  0.06
# 2                  Hotel  0.06
# 3  Vietnamese Restaurant  0.06
# 4                   Park  0.04
#
#
# ----Dufferin, Dovercourt Village----
#                 venue  freq
# 0                Café  0.11
# 1         Coffee Shop  0.09
# 2                Park  0.08
# 3  Italian Restaurant  0.05
# 4    Sushi Restaurant  0.05
#
#
# ----East Toronto, Broadview North (Old East York)----
#                   venue  freq
# 0           Coffee Shop  0.08
# 1                  Café  0.07
# 2      Greek Restaurant  0.06
# 3           Pizza Place  0.04
# 4  Ethiopian Restaurant  0.03
#
#
# ----Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1      Breakfast Spot  0.06
# 2  College Rec Center  0.06
# 3   Fish & Chips Shop  0.06
# 4                Café  0.06
#
#
# ----Fairview, Henry Farm, Oriole----
#                   venue  freq
# 0        Clothing Store  0.11
# 1           Coffee Shop  0.11
# 2            Restaurant  0.04
# 3             Juice Bar  0.04
# 4  Fast Food Restaurant  0.04
#
#
# ----First Canadian Place, Underground city----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                 Café  0.06
# 2                Hotel  0.06
# 3           Restaurant  0.03
# 4  Japanese Restaurant  0.03
#
#
# ----Forest Hill North & West, Forest Hill Road Park----
#                 venue  freq
# 0                Café  0.06
# 1                Bank  0.06
# 2  Italian Restaurant  0.06
# 3                Park  0.06
# 4         Coffee Shop  0.06
#
#
# ----Garden District, Ryerson----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1            Gastropub  0.05
# 2  Japanese Restaurant  0.04
# 3                Hotel  0.03
# 4                 Café  0.03
#
#
# ----Glencairn----
#                   venue  freq
# 0         Grocery Store  0.12
# 1  Fast Food Restaurant  0.09
# 2           Gas Station  0.06
# 3                  Park  0.06
# 4           Pizza Place  0.06
#
#
# ----Golden Mile, Clairlea, Oakridge----
#           venue  freq
# 0  Intersection  0.08
# 1      Bus Line  0.08
# 2        Bakery  0.08
# 3   Coffee Shop  0.08
# 4          Park  0.04
#
#
# ----Guildwood, Morningside, West Hill----
#                   venue  freq
# 0           Pizza Place  0.17
# 1  Fast Food Restaurant  0.09
# 2                  Bank  0.09
# 3   Fried Chicken Joint  0.04
# 4           Coffee Shop  0.04
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#                  venue  freq
# 0                 Café  0.07
# 1          Coffee Shop  0.07
# 2                Hotel  0.05
# 3                  Gym  0.04
# 4  Japanese Restaurant  0.04
#
#
# ----High Park, The Junction South----
#                venue  freq
# 0               Café  0.08
# 1                Bar  0.06
# 2        Coffee Shop  0.05
# 3  Convenience Store  0.04
# 4    Thai Restaurant  0.04
#
#
# ----Hillcrest Village----
#                venue  freq
# 0        Coffee Shop  0.09
# 1               Park  0.09
# 2           Pharmacy  0.09
# 3  Convenience Store  0.05
# 4  Recreation Center  0.05
#
#
# ----Humber Summit----
#                venue  freq
# 0  Electronics Store   0.2
# 1             Bakery   0.1
# 2      Shopping Mall   0.1
# 3               Park   0.1
# 4        Pizza Place   0.1
#
#
# ----Humberlea, Emery----
#                venue  freq
# 0  Convenience Store  0.14
# 1        Golf Course  0.14
# 2   Storage Facility  0.14
# 3               Park  0.14
# 4     Discount Store  0.14
#
#
# ----Humewood-Cedarvale----
#                venue  freq
# 0        Pizza Place  0.11
# 1        Coffee Shop  0.07
# 2  Convenience Store  0.07
# 3      Grocery Store  0.07
# 4  Korean Restaurant  0.04
#
#
# ----India Bazaar, The Beaches West----
#                   venue  freq
# 0     Indian Restaurant  0.09
# 1           Coffee Shop  0.05
# 2            Restaurant  0.04
# 3  Fast Food Restaurant  0.04
# 4                 Beach  0.04
#
#
# ----Islington Avenue, Humber Valley Village----
#                venue  freq
# 0           Pharmacy  0.17
# 1  Convenience Store  0.08
# 2               Café  0.08
# 3       Skating Rink  0.08
# 4        Golf Course  0.08
#
#
# ----Kennedy Park, Ionview, East Birchmount Park----
#                   venue  freq
# 0    Chinese Restaurant  0.14
# 1           Coffee Shop  0.11
# 2        Discount Store  0.11
# 3         Grocery Store  0.07
# 4  Fast Food Restaurant  0.07
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                            venue  freq
# 0                           Café  0.10
# 1  Vegetarian / Vegan Restaurant  0.05
# 2                    Coffee Shop  0.05
# 3                            Bar  0.04
# 4                    Yoga Studio  0.03
#
#
# ----Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens----
#              venue  freq
# 0         Pharmacy  0.14
# 1             Bank  0.07
# 2      Coffee Shop  0.07
# 3   Sandwich Place  0.07
# 4  Supplement Shop  0.07
#
#
# ----Lawrence Manor, Lawrence Heights----
#                    venue  freq
# 0   Fast Food Restaurant  0.07
# 1            Coffee Shop  0.07
# 2             Restaurant  0.07
# 3           Dessert Shop  0.05
# 4  Vietnamese Restaurant  0.05
#
#
# ----Lawrence Park----
#                   venue  freq
# 0          College Quad  0.12
# 1           College Gym  0.12
# 2                  Park  0.12
# 3  Gym / Fitness Center  0.12
# 4                 Trail  0.12
#
#
# ----Leaside----
#                     venue  freq
# 0     Sporting Goods Shop  0.07
# 1             Coffee Shop  0.07
# 2            Burger Joint  0.05
# 3           Grocery Store  0.05
# 4  Furniture / Home Store  0.05
#
#
# ----Little Portugal, Trinity----
#                            venue  freq
# 0                           Café  0.08
# 1                            Bar  0.06
# 2                     Restaurant  0.06
# 3  Vegetarian / Vegan Restaurant  0.05
# 4                    Coffee Shop  0.04
#
#
# ----Malvern, Rouge----
#                   venue  freq
# 0           Coffee Shop  0.11
# 1  Fast Food Restaurant  0.11
# 2            Restaurant  0.11
# 3                 Trail  0.11
# 4                   Gym  0.06
#
#
# ----Milliken, Agincourt North, Steeles East, L'Amoreaux East----
#                 venue  freq
# 0  Chinese Restaurant  0.17
# 1                Park  0.07
# 2        Intersection  0.07
# 3         Pizza Place  0.07
# 4   Korean Restaurant  0.07
#
#
# ----Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West----
#                   venue  freq
# 0            Restaurant  0.08
# 1  Gym / Fitness Center  0.07
# 2         Grocery Store  0.03
# 3         Burrito Place  0.03
# 4    Italian Restaurant  0.03
#
#
# ----Moore Park, Summerhill East----
#                 venue  freq
# 0       Grocery Store  0.08
# 1  Italian Restaurant  0.06
# 2         Coffee Shop  0.06
# 3                Park  0.05
# 4     Thai Restaurant  0.05
#
#
# ----New Toronto, Mimico South, Humber Bay Shores----
#                 venue  freq
# 0                Park  0.11
# 1                 Pub  0.06
# 2              Bakery  0.06
# 3  Italian Restaurant  0.06
# 4       Grocery Store  0.06
#
#
# ----North Park, Maple Leaf Park, Upwood Park----
#                       venue  freq
# 0               Coffee Shop  0.18
# 1         Convenience Store  0.09
# 2        Dim Sum Restaurant  0.09
# 3               Gas Station  0.09
# 4  Mediterranean Restaurant  0.09
#
#
# ----North Toronto West,  Lawrence Park----
#                 venue  freq
# 0  Italian Restaurant  0.07
# 1         Coffee Shop  0.07
# 2        Skating Rink  0.07
# 3     Thai Restaurant  0.04
# 4  Mexican Restaurant  0.04
#
#
# ----Northwest, West Humber - Clairville----
#                   venue  freq
# 0           Coffee Shop  0.33
# 1                 Hotel  0.33
# 2                Lounge  0.33
# 3             Newsagent  0.00
# 4  Other Great Outdoors  0.00
#
#
# ----Northwood Park, York University----
#                     venue  freq
# 0             Coffee Shop  0.14
# 1  Furniture / Home Store  0.14
# 2             Pizza Place  0.09
# 3             Frame Store  0.05
# 4              Sports Bar  0.05
#
#
# ----Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East----
#                   venue  freq
# 0                  Park  0.33
# 1        Ice Cream Shop  0.11
# 2    Italian Restaurant  0.11
# 3         Shopping Mall  0.11
# 4  Gym / Fitness Center  0.11
#
#
# ----Parkdale, Roncesvalles----
#               venue  freq
# 0       Coffee Shop  0.05
# 1     Grocery Store  0.04
# 2  Sushi Restaurant  0.04
# 3              Café  0.04
# 4               Bar  0.04
#
#
# ----Parkview Hill, Woodbine Gardens----
#                   venue  freq
# 0               Brewery  0.11
# 1           Pizza Place  0.11
# 2  Gym / Fitness Center  0.11
# 3    Athletics & Sports  0.05
# 4        Breakfast Spot  0.05
#
#
# ----Parkwoods----
#            venue  freq
# 0           Park  0.10
# 1       Bus Stop  0.07
# 2  Shopping Mall  0.07
# 3       Pharmacy  0.07
# 4            ATM  0.03
#
#
# ----Queen's Park, Ontario Provincial Government----
#               venue  freq
# 0       Coffee Shop  0.09
# 1              Park  0.05
# 2  Sushi Restaurant  0.04
# 3              Café  0.04
# 4       Pizza Place  0.03
#
#
# ----Regent Park, Harbourfront----
#          venue  freq
# 0  Coffee Shop  0.15
# 1         Café  0.05
# 2          Pub  0.04
# 3         Park  0.04
# 4      Theater  0.04
#
#
# ----Richmond, Adelaide, King----
#          venue  freq
# 0  Coffee Shop  0.08
# 1         Café  0.07
# 2        Hotel  0.06
# 3      Theater  0.04
# 4  Pizza Place  0.03
#
#
# ----Rosedale----
#                  venue  freq
# 0        Grocery Store  0.10
# 1                 Park  0.10
# 2  Rental Car Location  0.05
# 3             Pie Shop  0.05
# 4       Breakfast Spot  0.05
#
#
# ----Roselawn----
#                 venue  freq
# 0    Sushi Restaurant  0.12
# 1  Italian Restaurant  0.08
# 2         Coffee Shop  0.08
# 3            Pharmacy  0.08
# 4    Asian Restaurant  0.08
#
#
# ----Rouge Hill, Port Union, Highland Creek----
#                 venue  freq
# 0      Breakfast Spot   0.2
# 1                Park   0.2
# 2        Burger Joint   0.2
# 3          Playground   0.2
# 4  Italian Restaurant   0.2
#
#
# ----Runnymede, Swansea----
#          venue  freq
# 0  Coffee Shop  0.11
# 1         Café  0.10
# 2       Bakery  0.06
# 3  Pizza Place  0.06
# 4          Pub  0.04
#
#
# ----Runnymede, The Junction North----
#          venue  freq
# 0  Coffee Shop  0.11
# 1  Pizza Place  0.09
# 2      Brewery  0.07
# 3     Bus Line  0.05
# 4  Gas Station  0.05
#
#
# ----Scarborough Village----
#                  venue  freq
# 0       Ice Cream Shop  0.18
# 1          Pizza Place  0.09
# 2  Japanese Restaurant  0.09
# 3          Coffee Shop  0.09
# 4       Sandwich Place  0.09
#
#
# ----South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens----
#                venue  freq
# 0      Grocery Store  0.17
# 1        Pizza Place  0.17
# 2  Electronics Store  0.06
# 3        Video Store  0.06
# 4         Beer Store  0.06
#
#
# ----St. James Town----
#          venue  freq
# 0  Coffee Shop  0.09
# 1         Café  0.07
# 2   Restaurant  0.04
# 3    Gastropub  0.04
# 4      Theater  0.03
#
#
# ----St. James Town, Cabbagetown----
#                  venue  freq
# 0                Diner  0.06
# 1                 Café  0.06
# 2           Restaurant  0.06
# 3  Japanese Restaurant  0.06
# 4            Gastropub  0.06
#
#
# ----Steeles West, L'Amoreaux West----
#                 venue  freq
# 0  Chinese Restaurant  0.13
# 1        Intersection  0.10
# 2         Pizza Place  0.07
# 3                Bank  0.07
# 4              Bakery  0.07
#
#
# ----Stn A PO Boxes----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                 Café  0.06
# 2                Hotel  0.04
# 3  Japanese Restaurant  0.04
# 4   Seafood Restaurant  0.03
#
#
# ----Studio District----
#                    venue  freq
# 0            Coffee Shop  0.07
# 1    American Restaurant  0.05
# 2                    Bar  0.05
# 3  Vietnamese Restaurant  0.05
# 4                Brewery  0.05
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1    Sushi Restaurant  0.07
# 2  Italian Restaurant  0.05
# 3     Thai Restaurant  0.05
# 4                Park  0.04
#
#
# ----The Annex, North Midtown, Yorkville----
#                            venue  freq
# 0                           Café  0.06
# 1                    Coffee Shop  0.05
# 2             Italian Restaurant  0.05
# 3  Vegetarian / Vegan Restaurant  0.04
# 4                            Gym  0.03
#
#
# ----The Beaches----
#                  venue  freq
# 0          Coffee Shop  0.06
# 1                  Pub  0.06
# 2          Pizza Place  0.05
# 3                Beach  0.05
# 4  Japanese Restaurant  0.04
#
#
# ----The Danforth West, Riverdale----
#                   venue  freq
# 0      Greek Restaurant  0.11
# 1                  Café  0.06
# 2                   Pub  0.05
# 3           Coffee Shop  0.05
# 4  Fast Food Restaurant  0.03
#
#
# ----The Kingsway, Montgomery Road, Old Mill North----
#           venue  freq
# 0   Coffee Shop  0.09
# 1          Park  0.04
# 2          Bank  0.04
# 3  Burger Joint  0.04
# 4  Dessert Shop  0.04
#
#
# ----Thorncliffe Park----
#                venue  freq
# 0        Coffee Shop  0.11
# 1  Indian Restaurant  0.09
# 2      Grocery Store  0.06
# 3        Supermarket  0.04
# 4  Afghan Restaurant  0.04
#
#
# ----Toronto Dominion Centre, Design Exchange----
#                  venue  freq
# 0          Coffee Shop  0.09
# 1                 Café  0.07
# 2                Hotel  0.06
# 3  Japanese Restaurant  0.04
# 4                  Gym  0.03
#
#
# ----University of Toronto, Harbord----
#                            venue  freq
# 0                           Café  0.08
# 1                         Bakery  0.05
# 2                     Restaurant  0.04
# 3                    Coffee Shop  0.04
# 4  Vegetarian / Vegan Restaurant  0.04
#
#
# ----Victoria Village----
#                   venue  freq
# 0           Coffee Shop  0.15
# 1     French Restaurant  0.08
# 2         Grocery Store  0.08
# 3  Gym / Fitness Center  0.08
# 4                  Park  0.08
#
#
# ----West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale----
#             venue  freq
# 0            Park  0.20
# 1           Hotel  0.13
# 2     Pizza Place  0.13
# 3   Grocery Store  0.07
# 4  Clothing Store  0.07
#
#
# ----Westmount----
#                 venue  freq
# 0         Pizza Place  0.18
# 1         Gas Station  0.12
# 2      Ice Cream Shop  0.06
# 3  Golf Driving Range  0.06
# 4      Discount Store  0.06
#
#
# ----Weston----
#                  venue  freq
# 0        Train Station  0.17
# 1                Diner  0.08
# 2         Skating Rink  0.08
# 3          Pizza Place  0.08
# 4  Fried Chicken Joint  0.08
#
#
# ----Wexford, Maryvale----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.14
# 1              Grocery Store  0.10
# 2                Pizza Place  0.10
# 3               Burger Joint  0.07
# 4  Indian Chinese Restaurant  0.03
#
#
# ----Willowdale, Newtonbrook----
#                        venue  freq
# 0          Korean Restaurant  0.17
# 1                       Café  0.10
# 2  Middle Eastern Restaurant  0.07
# 3                Pizza Place  0.07
# 4                Coffee Shop  0.07
#
#
# ----Willowdale, Willowdale East----
#                  venue  freq
# 0          Coffee Shop  0.07
# 1     Ramen Restaurant  0.06
# 2      Bubble Tea Shop  0.06
# 3    Korean Restaurant  0.06
# 4  Japanese Restaurant  0.05
#
#
# ----Willowdale, Willowdale West----
#                venue  freq
# 0           Pharmacy   0.2
# 1  Convenience Store   0.1
# 2        Pizza Place   0.1
# 3           Bus Line   0.1
# 4             Bakery   0.1
#
#
# ----Woburn----
#                 venue  freq
# 0                Park  0.22
# 1         Coffee Shop  0.22
# 2   Mobile Phone Shop  0.11
# 3  Chinese Restaurant  0.11
# 4            Pharmacy  0.11
#
#
# ----Woodbine Heights----
#             venue  freq
# 0            Park  0.11
# 1     Coffee Shop  0.11
# 2            Café  0.07
# 3     Pizza Place  0.07
# 4  Sandwich Place  0.07
#
#
# ----York Mills West----
#                venue  freq
# 0         Restaurant  0.22
# 1               Park  0.17
# 2  French Restaurant  0.06
# 3        Coffee Shop  0.06
# 4      Bowling Alley  0.06
#
#
# ----York Mills, Silver Hills----
#           venue  freq
# 0          Park  0.75
# 1          Pool  0.25
# 2           ATM  0.00
# 3  Neighborhood  0.00
# 4  Optical Shop  0.00

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                      Neighbourhood  ... 10th Most Common Venue
# 0                                        Agincourt  ...             Restaurant
# 1                           Alderwood, Long Branch  ...          Shopping Mall
# 2  Bathurst Manor, Wilson Heights, Downsview North  ...         Sandwich Place
# 3                                  Bayview Village  ...                   Park
# 4                Bedford Park, Lawrence Manor East  ...                 Bakery
#
# [5 rows x 11 columns]

# %% [markdown]
# Clustering analysis

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 3, 3, 3, 2, 2, 1, 2, 2, 2], dtype=int32)

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = df

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

toronto_merged.head() # check the last columns!
# Out:
#   PostalCode           Borough  ... 9th Most Common Venue 10th Most Common Venue
# 0        M3A        North York  ...  Fast Food Restaurant           Skating Rink
# 1        M4A        North York  ...           Golf Course          Grocery Store
# 2        M5A  Downtown Toronto  ...                 Diner     Italian Restaurant
# 3        M6A        North York  ...   Fried Chicken Joint           Dessert Shop
# 4        M7A  Downtown Toronto  ...             Bookstore       Ramen Restaurant
#
# [5 rows x 17 columns]

# %%
toronto_merged = toronto_merged.dropna(subset=['Cluster Labels'])
toronto_merged['Cluster Labels'] = toronto_merged['Cluster Labels'].astype(int)

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_3225ed1498774adab7399aeb3747dc2f%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3225ed1498774adab7399aeb3747dc2f%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_3225ed1498774adab7399aeb3747dc2f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_3225ed1498774adab7399aeb3747dc2f%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_0b68b93dec5146d8aef8e43c1d686dd3%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...
